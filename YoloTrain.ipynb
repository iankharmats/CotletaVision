# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#копируем даннные из гугл диска в среду ноубука
# !cp /content/gdrive/MyDrive/CutletVision/data.zip /content

# %%
# !unzip -q /content/data.zip -d /content/custom_data

# %%
# !wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py

#разделяем выборку на обучающую и валидиционную с помощью скрипта
# !python train_val_split.py --datapath="/content/custom_data" --train_pct=0.9
# Out:
# --2025-07-24 15:33:49--  https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/plain]
# Saving to: ‘/content/train_val_split.py’
#
# /content/train_val_ 100%[===================>]   3.13K  --.-KB/s    in 0s
#
# 2025-07-24 15:33:49 (41.6 MB/s) - ‘/content/train_val_split.py’ saved [3203/3203]
#
# Created folder at /content/data/train/images.
# Created folder at /content/data/train/labels.
# Created folder at /content/data/validation/images.
# Created folder at /content/data/validation/labels.
# Number of image files: 617
# Number of annotation files: 616
# Images moving to train: 555
# Images moving to validation: 62

# %%
import yaml
import os

#создаем файт дата.yaml для того чтобы модель знала какие классы есть в выборке
def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Читаем файл классы.txt чтобы узнать какие есть классы
  if not os.path.exists(path_to_classes_txt):
    print(f'Нет файла с классами, создайте файл classes.txt и переместите в {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  data = {
      'path': '/content/data',
      'train': 'train/images',
      'val': 'validation/images',
      'nc': number_of_classes,
      'names': classes
  }

  # Записываем данные в yaml файл
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Файл создан в {path_to_data_yaml}')

  return

# Адреса файлов
path_to_classes_txt = '/content/custom_data/classes.txt'
path_to_data_yaml = '/content/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nДанные полученного файла:\n')
# !cat /content/data.yaml
# Out:
# Файл создан в /content/data.yaml
#
# Данные полученного файла:
#
# path: /content/data
# train: train/images
# val: validation/images
# nc: 33
# names:
# - borsch
# - red_compote
# - boiled_potato
# - french-style_pork
# - vinaigrette
# - cucumber_salad_with_radish
# - yellow_compote
# - fried_potato
# - white_bread
# - black_bread
# - black_cutlet
# - grilled_sausage
# - vegetables
# - korean_carrot
# - plov
# - fish_nugget
# - pasta
# - boiled_sausage
# - grechka
# - pork_in_boyar_style
# - yellow_juice
# - fish_cutlet
# - oval_bun
# - olivier
# - rice
# - eclair
# - caesar
# - rassolnik
# - circle_bun
# - vegetable_salad
# - greece_salad
# - circle_black_cutlet
# - circle_bright_cuttlet

# %%
# !rm -rf /content/runs/

# %%
# Обучение модели
# !yolo detect train data=/content/data.yaml model=/content/my_modelN.pt epochs=40 imgsz=960 batch=32 flipud = 0.5 pretrained=False
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict model=runs/detect/train3/weights/best.pt source=data/validation/images save=True
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,588,587 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/61 /content/data/validation/images/20250706_153749.jpg: 736x960 1 borsch, 1 red_compote, 1 boiled_potato, 1 french-style_pork, 1 cucumber_salad_with_radish, 51.4ms
# image 2/61 /content/data/validation/images/20250706_153800.jpg: 736x960 1 borsch, 1 boiled_potato, 1 french-style_pork, 1 cucumber_salad_with_radish, 1 yellow_compote, 11.8ms
# image 3/61 /content/data/validation/images/20250706_153903.jpg: 736x960 1 boiled_potato, 1 french-style_pork, 1 vinaigrette, 1 cucumber_salad_with_radish, 1 yellow_compote, 1 black_bread, 11.8ms
# image 4/61 /content/data/validation/images/20250706_154624.jpg: 736x960 1 borsch, 1 cucumber_salad_with_radish, 1 yellow_compote, 2 white_breads, 11.7ms
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# Create "{ModelName}" folder to store model weights and train results
ModelName='yoloLAST'
# !mkdir /content/{ModelName}
# !cp /content/runs/detect/train3/weights/best.pt /content/{ModelName}/{ModelName}.pt
# !cp -r /content/runs/detect/train3 /content/{ModelName}

# %%
# Zip into "{ModelName}.zip"
# %cd {ModelName}
# !zip /content/{ModelName}.zip {ModelName}.pt
# !zip -r /content/{ModelName}.zip train3
# %cd /content

from google.colab import files
files.download(f'/content/{ModelName}.zip')
# Out:
# /content/yoloLAST
# updating: yoloLAST.pt (deflated 10%)
#   adding: train3/ (stored 0%)
#   adding: train3/train_batch540.jpg (deflated 6%)
#   adding: train3/train_batch2.jpg (deflated 4%)
#   adding: train3/BoxR_curve.png (deflated 16%)
#   adding: train3/confusion_matrix_normalized.png (deflated 18%)
#   adding: train3/train_batch542.jpg (deflated 8%)
#   adding: train3/train_batch541.jpg (deflated 7%)
#   adding: train3/args.yaml (deflated 53%)
#   adding: train3/labels.jpg (deflated 26%)
#   adding: train3/val_batch0_pred.jpg (deflated 6%)
#   adding: train3/BoxF1_curve.png (deflated 11%)
#   adding: train3/train_batch0.jpg (deflated 3%)
#   adding: train3/labels_correlogram.jpg (deflated 41%)
#   adding: train3/BoxP_curve.png (deflated 12%)
#   adding: train3/BoxPR_curve.png (deflated 28%)
#   adding: train3/weights/ (stored 0%)
#   adding: train3/weights/last.pt (deflated 10%)
#   adding: train3/weights/best.pt (deflated 10%)
# ...

# %%
# !rm -rf /content/
